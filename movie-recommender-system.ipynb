# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('TMDB.csv')

# %%
movies.head(1)
# Out:
#    show_id      title  vote_average  vote_count    status release_date  \
# 0    27205  Inception         8.364       34495  Released   2010-07-15
#
#      revenue  runtime  adult                     backdrop_path  ...  \
# 0  825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
#
#    original_title                                        description  \
# 0       Inception  Cobb, a skilled thief who commits corporate es...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
#
#                                 tagline                           listed_in  \
# 0  Your mind is the scene of the crime.  Action, Science Fiction, Adventure
#
#                                             director  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
#
#                        production_countries  \
# 0  United Kingdom, United States of America
#
#                      spoken_languages  \
# ...

# %%
movies.shape
# Out:
# (1190651, 24)

# %%
# listed_in
# show_id
# title
# description
# cast
# directo
#keywordds
movies = movies[['show_id','title','description','listed_in']]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190651 entries, 0 to 1190650
# Data columns (total 4 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   show_id      1190651 non-null  int64
#  1   title        1190638 non-null  object
#  2   description  941896 non-null   object
#  3   listed_in    703695 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 36.3+ MB

# %%
movies.head()
# Out:
#    show_id            title  \
# 0    27205        Inception
# 1   157336     Interstellar
# 2      155  The Dark Knight
# 3    19995           Avatar
# 4    24428     The Avengers
#
#                                          description  \
# 0  Cobb, a skilled thief who commits corporate es...
# 1  The adventures of a group of explorers who mak...
# 2  Batman raises the stakes in his war on crime. ...
# 3  In the 22nd century, a paraplegic Marine is di...
# 4  When an unexpected enemy emerges and threatens...
#
#                                      listed_in
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure

# %%
movies.isnull().sum()
# Out:
# show_id             0
# title              13
# description    248755
# listed_in      486956
# dtype: int64

# %%
movies.dropna(inplace=True)
movies.drop_duplicates(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.iloc[0].listed_in
# Out:
# 'Action, Science Fiction, Adventure'

# %%
def convert(obj):
  for i in obj:
      i['name']

# %%
movies['description'][2]
# Out:
# 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.'

# %%
movies['description'] = movies['description'].apply(lambda x:x.split())

# %%
movies.head()
# Out:
#    show_id            title  \
# 0    27205        Inception
# 1   157336     Interstellar
# 2      155  The Dark Knight
# 3    19995           Avatar
# 4    24428     The Avengers
#
#                                          description  \
# 0  [Cobb,, a, skilled, thief, who, commits, corpo...
# 1  [The, adventures, of, a, group, of, explorers,...
# 2  [Batman, raises, the, stakes, in, his, war, on...
# 3  [In, the, 22nd, century,, a, paraplegic, Marin...
# 4  [When, an, unexpected, enemy, emerges, and, th...
#
#                                      listed_in
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure

# %%
# Instead of selecting only a subset of columns, keep all original columns.
# movies = movies[['show_id','title','description','listed_in']] # Comment out this line.

# Alternatively, if you need to drop columns,
# do it after creating the 'tags' column:
movies['tags'] = movies['description'] + movies['listed_in'].str.split(',').apply(lambda x: [i.strip() for i in x])
# Now, drop unnecessary columns if required:
movies = movies[['show_id', 'title', 'description', 'listed_in', 'tags']]

# %%
movies['tags'] = movies['description'] + movies['listed_in'].str.split(',').apply(lambda x: [i.strip() for i in x]) + movies['cast'].str.split(',').apply(lambda x: [i.strip() for i in x]) + movies['director'].str.split(',').apply(lambda x: [i.strip() for i in x])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cast'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-c180d8e368ce> in <cell line: 0>()
# ...

# %%
movies.head()
# Out:
#    show_id            title  \
# 0    27205        Inception
# 1   157336     Interstellar
# 2      155  The Dark Knight
# 3    19995           Avatar
# 4    24428     The Avengers
#
#                                          description  \
# 0  [Cobb,, a, skilled, thief, who, commits, corpo...
# 1  [The, adventures, of, a, group, of, explorers,...
# 2  [Batman, raises, the, stakes, in, his, war, on...
# 3  [In, the, 22nd, century,, a, paraplegic, Marin...
# 4  [When, an, unexpected, enemy, emerges, and, th...
#
#                                      listed_in  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                                 tags
# 0  [Cobb,, a, skilled, thief, who, commits, corpo...
# 1  [The, adventures, of, a, group, of, explorers,...
# ...

# %%
new_df = movies[['show_id','title','tags']]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-28-ad44e9ca1347>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df['tags'][2]
# Out:
# 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker. Drama Action Crime Thriller'

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# <ipython-input-30-8b60b591a07f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head()
# Out:
#    show_id            title                                               tags
# 0    27205        Inception  cobb, a skilled thief who commits corporate es...
# 1   157336     Interstellar  the adventures of a group of explorers who mak...
# 2      155  The Dark Knight  batman raises the stakes in his war on crime. ...
# 3    19995           Avatar  in the 22nd century, a paraplegic marine is di...
# 4    24428     The Avengers  when an unexpected enemy emerges and threatens...

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
  y = []
  for i in text.split():
      y.append(ps.stem(i))
  return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# <ipython-input-35-be18a4346d89>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
new_df['tags'][2]
# Out:
# 'batman rais the stake in hi war on crime. with the help of lt. jim gordon and district attorney harvey dent, batman set out to dismantl the remain crimin organ that plagu the streets. the partnership prove to be effective, but they soon find themselv prey to a reign of chao unleash by a rise crimin mastermind known to the terrifi citizen of gotham as the joker. drama action crime thriller'

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=6000,stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors

# %%
vectors[2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-23409dee0b36> in <cell line: 0>()
# ----> 1 vectors[2]
#
# NameError: name 'vectors' is not defined

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '10', '11', ..., 'özay', 'özge', 'ünlüoğlu'], dtype=object)

# %%
ps.stem('dancing')
# Out:
# 'danc'

# %%
stem('to protect his family from a powerful drug lord, skilled thief mehdi and his expert team of robbers are pulled into a violent and deadly turf war. crime tv shows international tv shows tv action & adventure sami bouajila tracy gotoas samuel jouy nabiha akkari sofia lesaffre salim kechiouche noureddine farihi geert van rampelberg bakary diombera julien leclercq')
# Out:
# 'to protect hi famili from a power drug lord, skill thief mehdi and hi expert team of robber are pull into a violent and deadli turf war. crime tv show intern tv show tv action & adventur sami bouajila traci gotoa samuel jouy nabiha akkari sofia lesaffr salim kechiouch noureddin farihi geert van rampelberg bakari diombera julien leclercq'

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])[1:6]
# Out:
# [(2528, 0.4217326631901446),
#  (1618, 0.4173111630559929),
#  (6, 0.4135850959342556),
#  (3465, 0.4111032083956733),
#  (4308, 0.4079015827236455)]

# %%
def recommend(movie):
    movie_index = new_df[new_df['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]

    for i in movies_list:
      print(new_df.iloc[i[0]].title)

# %%
recommend('Ganglands')
# Out:
# The Willoughbys
# Hop
# Chitty Chitty Bang Bang
# Over the Moon
# Turbo

# %%
new_df.iloc[444].title
# Out:
# 'Security'
